# %%
'''2. Do the EDA on the given dataset: Lung cancer, and extract some useful information from this.
Dataset Description:

Lung cancer is one of the most prevalent and deadly forms of cancer worldwide, presenting significant
challenges in early detection and effective treatment. To aid in the global effort to understand and combat this
disease, we are excited to introduce our comprehensive Lung Cancer Dataset.'''
# Out:
# '2. Do the EDA on the given dataset: Lung cancer, and extract some useful information from this.\nDataset Description:\n\nLung cancer is one of the most prevalent and deadly forms of cancer worldwide, presenting significant\nchallenges in early detection and effective treatment. To aid in the global effort to understand and combat this\ndisease, we are excited to introduce our comprehensive Lung Cancer Dataset.'

# %%
# importing some libraryies for EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("lung_cancer.csv")
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
# Get information about DataSet
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
# Summary Stataics of numerical Colums
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
# Class distribution
class_distribution = df['LUNG_CANCER'].value_counts()
print("\nClass Distribution:")
print(class_distribution)
# Out:
# Class Distribution:
# LUNG_CANCER
# YES    1518
# NO     1482
# Name: count, dtype: int64

# %%
print(df.dtypes)
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
le = LabelEncoder()

# Convert GENDER and LUNG_CANCER to numeric values
df['GENDER'] = le.fit_transform(df['GENDER'])
df['LUNG_CANCER'] = le.fit_transform(df['LUNG_CANCER'])

# Calculate the correlation matrix
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                          GENDER       AGE   SMOKING  YELLOW_FINGERS   ANXIETY  \
# GENDER                 1.000000  0.010966 -0.028505        0.014412 -0.023891
# AGE                    0.010966  1.000000 -0.020289        0.016101  0.030051
# SMOKING               -0.028505 -0.020289  1.000000       -0.001497 -0.055562
# YELLOW_FINGERS         0.014412  0.016101 -0.001497        1.000000  0.012342
# ANXIETY               -0.023891  0.030051 -0.055562        0.012342  1.000000
# PEER_PRESSURE          0.010019  0.003850 -0.032041        0.011394 -0.024692
# CHRONIC_DISEASE        0.008488 -0.025655  0.045697       -0.013216  0.016903
# FATIGUE                0.002193 -0.002322  0.019635       -0.010761 -0.006250
# ALLERGY                0.013211  0.024915  0.004908       -0.005709 -0.001174
# WHEEZING              -0.009284 -0.018212  0.000571        0.004151 -0.016065
# ALCOHOL_CONSUMING     -0.009173 -0.020704  0.003022        0.027167 -0.001542
# ...

# %%
# Correlation matrix
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                          GENDER       AGE   SMOKING  YELLOW_FINGERS   ANXIETY  \
# GENDER                 1.000000  0.010966 -0.028505        0.014412 -0.023891
# AGE                    0.010966  1.000000 -0.020289        0.016101  0.030051
# SMOKING               -0.028505 -0.020289  1.000000       -0.001497 -0.055562
# YELLOW_FINGERS         0.014412  0.016101 -0.001497        1.000000  0.012342
# ANXIETY               -0.023891  0.030051 -0.055562        0.012342  1.000000
# PEER_PRESSURE          0.010019  0.003850 -0.032041        0.011394 -0.024692
# CHRONIC_DISEASE        0.008488 -0.025655  0.045697       -0.013216  0.016903
# FATIGUE                0.002193 -0.002322  0.019635       -0.010761 -0.006250
# ALLERGY                0.013211  0.024915  0.004908       -0.005709 -0.001174
# WHEEZING              -0.009284 -0.018212  0.000571        0.004151 -0.016065
# ALCOHOL_CONSUMING     -0.009173 -0.020704  0.003022        0.027167 -0.001542
# ...

# %%
# Plotting the correlation matrix
plt.figure(figsize=(12, 10),facecolor='lightgray')

# Set the font properties
font = FontProperties()
font.set_family('serif')  # Change font family here
font.set_style('italic')  # Change font style here
font.set_weight('bold')   # Change font weight here

sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, square=True, linewidths=.5)
plt.title('Correlation Matrix of Numerical Features', color='#F81313',  fontproperties=font, fontsize= 18)
plt.show()

# %%
# Select numerical features
num_features = df.select_dtypes(include=['int64', 'float64']).columns

# Set the font properties
font = {'family': 'serif', 'style': 'italic', 'weight': 'bold'}

# Create a figure with subplots
plt.figure(figsize=(20, 20), facecolor='lightgray')
plt.subplots_adjust(hspace=0.4, wspace=0.4)

# Determine the number of rows and columns for the subplots
num_rows = len(num_features) // 3 + (len(num_features) % 3 > 0)
num_cols = 3

# Loop through the numerical features and create a histogram for each
for idx, feature in enumerate(num_features):
    plt.subplot(num_rows, num_cols, idx + 1)
    sns.histplot(df[feature], kde=True, bins=20, color='#6AE89B')
    plt.title(f'Distribution of {feature}', color='#F81313', fontdict=font, fontsize=14)

# Show the plot
plt.show()

# %%
# Gender distribution
gender_distribution = df['GENDER'].value_counts()
gender_distribution
# Out:
# GENDER
# 1    1514
# 0    1486
# Name: count, dtype: int64

# %%
# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct='%1.1f%%', startangle=140, colors=['lightblue', 'lightcoral'])
plt.title('Gender Distribution in Lung Cancer Dataset')
plt.show()

# %%
# Select numerical features
num_features = ['AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY', 'PEER_PRESSURE',
                'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
                'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
                'SWALLOWING_DIFFICULTY', 'CHEST_PAIN']

# Melt the dataset for seaborn's boxplot
melted_data = df.melt(id_vars=['LUNG_CANCER'], value_vars=num_features, var_name='Feature', value_name='Value')

# Set the font properties
font = {'family': 'serif', 'style': 'italic', 'weight': 'bold'}

# Create the box plot
plt.figure(figsize=(20, 10))
sns.boxplot(x='Feature', y='Value', hue='LUNG_CANCER', data=melted_data)
plt.xticks(rotation=90)
plt.title('Features vs LUNG_CANCER', fontdict=font)
plt.show()

# %%
# Additional insights
# Example: Analyzing the relationship between age and lung cancer
plt.figure(figsize=(10, 5),facecolor='lightgrey')
font = FontProperties()
font.set_family('serif')  # Change font family here
font.set_style('italic')  # Change font style here
font.set_weight('bold')   # Change font weight here
plt.xlabel('Age', color='#5CD3E6',  fontproperties=font, fontsize= 16)
plt.ylabel('Count', color='#5CD3E6',  fontproperties=font, fontsize= 16)
sns.histplot(df[df['LUNG_CANCER'] == 'YES']['AGE'], color='red', kde=True, label='LUNG_CANCER: YES')
sns.histplot(df[df['LUNG_CANCER'] == 'NO']['AGE'], color='blue', kde=True, label='LUNG_CANCER: NO')
plt.legend()
plt.title('Age Distribution by Lung Cancer Status',color='#3CEE1C',  fontproperties=font, fontsize= 18)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
from scipy.stats import ttest_ind
num_features = df.select_dtypes(include=['int64', 'float64']).columns

# Separate data into two groups based on lung cancer diagnosis
group_yes = df[df['LUNG_CANCER'] == 'YES']
group_no = df[df['LUNG_CANCER'] == 'NO']

# Perform t-test for each numerical feature
t_test_results = {}
for feature in num_features:
    t_stat, p_value = ttest_ind(group_yes[feature], group_no[feature], equal_var=False)
    t_test_results[feature] = {'t_stat': t_stat, 'p_value': p_value}

# Convert results to a DataFrame for better visualization
t_test_df = pd.DataFrame(t_test_results).T
t_test_df.columns = ['t_statistic', 'p_value']

# Display the results
print(t_test_df)
# Out:
#                        t_statistic  p_value
# AGE                            NaN      NaN
# SMOKING                        NaN      NaN
# YELLOW_FINGERS                 NaN      NaN
# ANXIETY                        NaN      NaN
# PEER_PRESSURE                  NaN      NaN
# CHRONIC_DISEASE                NaN      NaN
# FATIGUE                        NaN      NaN
# ALLERGY                        NaN      NaN
# WHEEZING                       NaN      NaN
# ALCOHOL_CONSUMING              NaN      NaN
# COUGHING                       NaN      NaN
# SHORTNESS_OF_BREATH            NaN      NaN
# SWALLOWING_DIFFICULTY          NaN      NaN
# CHEST_PAIN                     NaN      NaN

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

num_features = df.select_dtypes(include=['int64', 'float64']).columns

# Perform ANOVA for each numerical feature
anova_results = {}
for feature in num_features:
    formula = f'{feature} ~ C(LUNG_CANCER)'
    model = ols(formula, data=df).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    anova_results[feature] = anova_table

# Display the results
for feature, result in anova_results.items():
    print(f'\nANOVA results for {feature}:')
    print(result)
# Out:
# ANOVA results for AGE:
#                       sum_sq      df         F    PR(>F)
# C(LUNG_CANCER)     829.18405     1.0  3.828456  0.050482
# Residual        649320.13295  2998.0       NaN       NaN
#
# ANOVA results for SMOKING:
#                     sum_sq      df         F    PR(>F)
# C(LUNG_CANCER)    0.151593     1.0  0.606286  0.436251
# Residual        749.605407  2998.0       NaN       NaN
#
# ANOVA results for YELLOW_FINGERS:
#                     sum_sq      df        F    PR(>F)
# C(LUNG_CANCER)    0.126716     1.0  0.50701  0.476491
# Residual        749.285284  2998.0      NaN       NaN
#
# ANOVA results for ANXIETY:
#                     sum_sq      df         F   PR(>F)
# C(LUNG_CANCER)    0.158204     1.0  0.632617  0.42646
# Residual        749.733796  2998.0       NaN      NaN
#
# ANOVA results for PEER_PRESSURE:
#                     sum_sq      df         F    PR(>F)
# C(LUNG_CANCER)    0.455511     1.0  1.821945  0.177184
# ...

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6), facecolor='lightgray')
sns.scatterplot(data=df, x='AGE', y='SMOKING', hue='LUNG_CANCER', palette=['red', 'blue'], alpha=0.7)

# Set title and labels
plt.title('Age vs Smoking with Lung Cancer Status', fontsize=18, color='#F81313', fontweight='bold', style='italic', family='serif')
plt.xlabel('Age', fontsize=14, fontweight='bold', style='italic', family='serif')
plt.ylabel('Smoking', fontsize=14, fontweight='bold', style='italic', family='serif')

# Show plot
plt.show()
