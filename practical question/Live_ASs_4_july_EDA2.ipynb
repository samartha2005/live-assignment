# %%
'''3. Do the Eda on this Dataset :Presidential Election Polls 2024 Dataset and extract useful information from
this:

Dataset Description:
This dataset co_prises the results of a nationwide presidential election poll conducted on March 4, 2024. The
data offers various insights but does not align with the official election results. You are encouraged to create
your notebooks and delve into the data for further exploration.'''
# Out:
# '3. Do the Eda on this Dataset :Presidential Election Polls 2024 Dataset and extract useful information from\nthis:\n\nDataset Description:\nThis dataset co_prises the results of a nationwide presidential election poll conducted on March 4, 2024. The\ndata offers various insights but does not align with the official election results. You are encouraged to create\nyour notebooks and delve into the data for further exploration.'

# %%
# importing some libraryies for EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("election2024.csv")
# Display the first few rows of the dataset
df.head()
# Out:
#                  id   sex   age federal_district  \
# 0  07169ed8148ce047  male  18.0  north caucasian
# 1  0716a4f3354cecdd  male  23.0  north caucasian
# 2  0716889b304ce79c  male  20.0            volga
# 3  07168e28b5cce563  male  22.0     northwestern
# 4  0716a563914ce549  male  21.0         southern
#
#                                    type_of_city    knows_election_date  \
# 0                                       village     named correct date
# 1                                       village     named correct date
# 2         city with population of less than 50k     named correct date
# 3  city with population of 1 million and higher  not sure or no answer
# 4  city with population of 1 million and higher     named correct date
#
#         will_vote candidate      television_usage      internet_usage  \
# 0        not sure     Putin  several times a week  over 4 hours a day
# 1        not sure     Putin      once half a year  over 4 hours a day
# ...

# %%
df.shape
# Out:
# (1600, 16)

# %%
# Get a summary of the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   object
#  2   age                  1600 non-null   float64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  job_type             692 non-null    object
#  14  company_type         879 non-null    object
# ...

# %%
# Display basic statistics
df.describe()
# Out:
#                age      weight1
# count  1600.000000  1600.000000
# mean     49.936250     1.000000
# std      16.901797     0.327084
# min      18.000000     0.468226
# 25%      37.000000     0.772224
# 50%      49.000000     0.921724
# 75%      64.000000     1.158913
# max      90.000000     2.515072

# %%
# Check for missing values
df.isnull().sum()
# Out:
# id                       0
# sex                      0
# age                      0
# federal_district         0
# type_of_city             0
# knows_election_date      0
# will_vote                0
# candidate                0
# television_usage         0
# internet_usage           0
# education                0
# income                   0
# employment               0
# job_type               908
# company_type           721
# weight1                  0
# dtype: int64

# %%
# Fill missing values with N/A
df.fillna('N/A')
# Out:
#                     id     sex   age federal_district  \
# 0     07169ed8148ce047    male  18.0  north caucasian
# 1     0716a4f3354cecdd    male  23.0  north caucasian
# 2     0716889b304ce79c    male  20.0            volga
# 3     07168e28b5cce563    male  22.0     northwestern
# 4     0716a563914ce549    male  21.0         southern
# ...                ...     ...   ...              ...
# 1595  0716b23c2c0cee3a    male  61.0          central
# 1596  07168254d14ceb55  female  80.0            volga
# 1597  071690f34d4ce164  female  76.0     northwestern
# 1598  0716bfa9c48ce79a  female  74.0          central
# 1599  07168088318cef88  female  76.0             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# ...

# %%
df.columns
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                      object
# sex                     object
# age                    float64
# federal_district        object
# type_of_city            object
# knows_election_date     object
# will_vote               object
# candidate               object
# television_usage        object
# internet_usage          object
# education               object
# income                  object
# employment              object
# job_type                object
# company_type            object
# weight1                float64
# dtype: object

# %%
# Convert the 'Age' column from float to int
df['age'] = df['age'].astype(int)

# %%
# after convert float to int
df.dtypes
# Out:
# id                      object
# sex                     object
# age                      int64
# federal_district        object
# type_of_city            object
# knows_election_date     object
# will_vote               object
# candidate               object
# television_usage        object
# internet_usage          object
# education               object
# income                  object
# employment              object
# job_type                object
# company_type            object
# weight1                float64
# dtype: object

# %%
# Display unique values for some columns
key_columns = ['sex','will_vote','education','income','job_type','company_type']
for column in key_columns:
    unique_values = df[column].unique()
    print(f"Unique values in the '{column}' column:")
    print(unique_values)
    print()  # Print a newline for better readability
# Out:
# Unique values in the 'sex' column:
# ['male' 'female']
#
# Unique values in the 'will_vote' column:
# ['not sure' 'definitely yes' 'likely no' 'definitely no' 'likely yes'
#  'struggle to answer']
#
# Unique values in the 'education' column:
# ['incomplete school education' 'college' 'bachelor degree' 'school'
#  'academic degree' 'no school education']
#
# Unique values in the 'income' column:
# ['very high' 'high' 'medium' 'low' 'very low' 'hard to say']
#
# Unique values in the 'job_type' column:
# [nan 'commercial organization' 'law enforcement agency'
#  'government agency' 'government, management, judicial bodies'
#  'non-profit agency' 'hard to say']
#
# Unique values in the 'company_type' column:
# ['farming' 'trade' 'law enforcement agency' nan
#  'tech, programming, communications' 'refused to answer'
#  'industry, manufacturing' 'other' 'housing and communal services'
#  'finances' 'education' 'healthcare' 'state administration'
# ...

# %%
# Create a bar plot with 'Gender' on the x-axis and the count of 'will_vote' responses
plt.figure(figsize=(10, 6),facecolor='lightgray')
# Set the font properties
font = FontProperties()
font.set_family('serif')  # Change font family here
font.set_style('italic')  # Change font style here
font.set_weight('bold')

sns.countplot(data=df, x='sex', hue='will_vote')
plt.title('Count of Will Vote Responses by Gender',color='#2FC4A4',  fontproperties=font, fontsize= 18)
plt.xlabel('Gender', color='purple',fontproperties=font, fontsize= 18)
plt.ylabel('Count', color='violet', fontproperties=font, fontsize= 18)
plt.legend(title='Will Vote')
plt.show()

# %%
# Plotting the histogram
plt.figure(figsize=(10, 6),facecolor='lightgray')  # Adjust size if necessary
# Set the font properties
font = FontProperties()
font.set_family('serif')  # Change font family here
font.set_style('italic')  # Change font style here
font.set_weight('bold')

plt.hist(df['type_of_city'], bins=3, color='red', edgecolor='black', alpha=0.7)
plt.xlabel('Type of City',color='#235176',fontproperties=font, fontsize= 18)
plt.ylabel('Frequency',color='#235176',fontproperties=font, fontsize= 18)
plt.title('Histogram of Type of City',color='#E2E931', fontproperties=font, fontsize= 18)
plt.grid(axis='y', linestyle='--', alpha=0.7)
# Rotate x-axis labels
plt.xticks(rotation=45)  # Adjust rotation angle as needed
plt.show()

# %%
# List of columns to plot
key_columns = ['age']

# Plotting each column
for col in key_columns:
    plt.figure(figsize=(12, 10))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=90)
    plt.show()

# %%
sns.lineplot(x = 'income', y = 'education', data = df, marker = 'o', color = 'purple')
# Out:
# <AxesSubplot: xlabel='income', ylabel='education'>

# %%
# Create a scatter plot to explore the relationship between 'job_type' and 'employment'
plt.figure(figsize=(10, 6),facecolor='#A6DDDA')
sns.scatterplot(x='job_type', y='employment', data=df)
# Set the font properties
font = FontProperties()
font.set_family('serif')  # Change font family here
font.set_style('italic')  # Change font style here
font.set_weight('bold')   # Change font weight here
plt.xlabel('job_type', color='red',  fontproperties=font, fontsize= 16)
plt.ylabel('employment', color='red',  fontproperties=font, fontsize= 16)
plt.title('Relationship between job_type and employment',  color='#3CEE1C',  fontproperties=font, fontsize= 18)
plt.xticks(rotation=45)
plt.grid(False)
plt.show()

# %%
#Poll results by candidate and region
plt.figure(figsize=(12, 8))
sns.boxplot(x='candidate', y='weight1', hue='employment', data=df)
plt.title('Poll Results by Candidate and Region')
plt.xticks(rotation=45)
plt.show()

# %%
num_col = ['age', 'weight1']
corr_df = df[num_col].corr()
corr_df
# Out:
#               age   weight1
# age      1.000000 -0.319715
# weight1 -0.319715  1.000000

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corr_df, annot=True, fmt=".2f", ax=ax, linewidths=0.5, linecolor="orange")
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.title("Correlation Between Different Variables")
plt.show()

# %%
cat_col = ['sex','federal_district','type_of_city','company_type','income','television_usage']
cat_col
# Out:
# ['sex',
#  'federal_district',
#  'type_of_city',
#  'company_type',
#  'income',
#  'television_usage']

# %%
df['television_usage'].unique()
# Out:
# array(['several times a week', 'once half a year', 'does not watch',
#        'less than 4 hours a day', 'over 4 hours a day',
#        'several times a month'], dtype=object)

# %%
df['age'].unique()
# Out:
# array([18, 23, 20, 22, 21, 27, 37, 43, 39, 36, 49, 60, 44, 61, 67, 29, 47,
#        32, 45, 35, 53, 71, 54, 55, 48, 66, 56, 68, 69, 33, 76, 77, 70, 86,
#        90, 75, 80, 24, 19, 25, 28, 31, 26, 30, 38, 40, 41, 52, 50, 51, 46,
#        63, 34, 42, 65, 73, 74, 72, 59, 57, 58, 78, 79, 62, 64, 82, 84, 85,
#        87, 83, 81])

# %%
df['internet_usage'].unique()
# Out:
# array(['over 4 hours a day', 'less than 4 hours a day',
#        'several times a week', 'does not use internet',
#        'several times a month', 'once half a year'], dtype=object)
